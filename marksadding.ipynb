# %% [markdown]
# <a href="https://colab.research.google.com/github/Preksha-Dadoo/Marks-Adder/blob/main/marksadding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random as r

# %%
df=pd.read_csv("/content/Mini Project - Marks Adding.csv")
df.head()
# Out:
#     Roll Num  Marks
# 0  102003542      1
# 1  102003640      1
# 2  102003725      1
# 3  102003307      1
# 4  102003458      1

# %%
df = df.sort_values(by="Roll Num")  #Sorting by roll numbers

# %%
df= df.groupby("Roll Num", as_index= False )["Marks"].sum()
df
# Out:
#       Roll Num  Marks
# 0    102003001      3
# 1    102003002      5
# 2    102003017      5
# 3    102003018      5
# 4    102003029      5
# ..         ...    ...
# 395  102196010      4
# 396  102197016      5
# 397  102197018      4
# 398  102197019      5
# 399  102197021      5
#
# [400 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Roll Num'].plot(kind='hist', bins=20, title='Roll Num')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Marks'].plot(kind='hist', bins=20, title='Marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...
